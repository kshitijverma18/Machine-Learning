# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")
import math
import random
import time
from numpy import log, e

# %%
def sigmoid(z): 
    return 1 / (1 + e**(-z))
#     return 1 / (1 + e**(-z)) - 0.0000001

# %%
def cost(wt, X, Y):
    Y_pred = sigmoid(X@wt)
    predict_0 = 0
    predict_1 = 0
    for i in range(len(Y)):
        if(Y[i]==0): predict_0 += (1 - Y[i]) * log(1 - Y_pred[i])
        else: predict_1 += Y[i] * log(Y_pred[i])
    return -(predict_1 + predict_0)/len(X)
#     return -(predict_1 + predict_0)

# %%
def accuracy(wt,X,Y):
    Y_pred = sigmoid(X@wt)
#     for i in range(len(Y_pred)):
#         if Y_pred[i]>=0.5: Y_pred[i]=1
#         else: Y_pred[i]=0
    Y_pred[Y_pred>=0.5]=1
    Y_pred[Y_pred<0.5]=0
    Y_pred = np.array(Y_pred)
    correct_class = np.sum(Y_pred==Y)   
    return 100*(correct_class/len(Y_pred))

# %%
def fpr(Y_pred,Y):
    tp, tn, fp, fn = 0, 0, 0, 0
    
    for i in range(len(Y)):
        if Y_pred[i] and Y[i]:
            tp += 1
        elif Y_pred[i] and not Y[i]:
            fn += 1
        elif not Y_pred[i] and Y[i]:
            fp += 1
        else:
            tn += 1
#     acc = (tp + tn) / (tp + tn + fp + fn)
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    Fscore = 2 * recall * precision / (recall + precision)
    return Fscore, recall, precision

# %%
def plot_graph_loss(x_plot,y_plot):
    fig = plt.figure(figsize=(8,5))
    plt.subplot(1,2,1)
    plt.plot(x_plot,y_plot)
    plt.xlabel("Epochs")
    plt.ylabel("Loss/Error")
    plt.title("Error vs Epoch for Gradient Descent")
    plt.tight_layout()
    plt.show()

# %%
def gd(X,Y):
    wt = np.zeros(X.shape[1])
    eta = 0.01
#     eta = 0.0000005
#     eta=50
    iterations = 15000
    N = len(X)
    loss = []
    epochs = []
    acc = []
    for itr in range(iterations+1):        
        Y_pred = sigmoid(X@wt)
        wt -= eta * ((Y_pred-Y)@X) / N
        if(itr%50 ==0):
            loss.append(cost(wt,X,Y))
            acc.append(accuracy(wt,X,Y))
#             print(loss[-1])
            epochs.append(itr)
    loss = np.array(loss)
    epochs = np.array(epochs)
    return wt,loss,epochs,acc

# %%
def sgd(X,Y):
    wt = np.zeros(X.shape[1])
    eta = 0.05
#     eta = 50
#     eta = 0.0000005
    iterations = 1000
    loss = []
    epochs = []
    acc = []
    N = len(X)
    for itr in range(iterations):
        Y_pred = np.array(X@wt)
        if(itr%50 == 0):
            loss.append(cost(wt,X,Y))
            acc.append(accuracy(wt,X,Y))
            epochs.append(itr)
        i=0
        for x,y in zip(X,Y):
            i=i+1
#             if((i*itr)%50 == 0):
#                 loss.append(cost(wt,X,Y))
#                 acc.append(accuracy(wt,X,Y))
#                 epochs.append(itr)
            t = x@wt
            y_pred = sigmoid(t)
            delta = y-y_pred
            wt+= eta*(delta*x) / N
#     loss.append(cost(wt,X,Y))
    loss = np.array(loss)
    epochs = np.array(epochs)
    return wt,loss,epochs,acc

# %%
def split(data):
    n=round(len(data)*0.7)
    np.random.shuffle(data)
    train = data[:n]
    test = data[n:]
    x_train, x_test, y_train, y_test = [], [], [], []
    for i in train:
        x_train.append(i[: (train.shape[1]-1)])
        y_train.append(i[(train.shape[1]-1)])
    
    for i in test:
        x_test.append(i[: (test.shape[1]-1)])
        y_test.append(i[(test.shape[1]-1)])
        
    x_train = np.array(x_train)
    m=np.mean(x_train,axis=0)
    s=np.std(x_train,axis=0)
    x_train=(x_train-m)/s
    ones=np.ones((x_train.shape[0],1))
    x_train = np.append(ones, x_train, axis=1)
    y_train = np.array(y_train)
    x_test = np.array(x_test)
    m=np.mean(x_test,axis=0)
    s=np.std(x_test,axis=0)
    x_test=(x_test-m)/s
    ones=np.ones((x_test.shape[0],1))
    x_test = np.append(ones, x_test, axis=1)
    y_test = np.array(y_test)
    return x_train, y_train, x_test, y_test

# %%
def predict(wt,X):
    Y_pred = sigmoid(X@wt)
    Y_pred[Y_pred>=0.5]=1
    Y_pred[Y_pred<0.5]=0
    Y_pred = np.array(Y_pred)
    return Y_pred

# %%
def main():
    start=time.time()
    data = pd.read_csv('dataset_LR.csv')
    data = np.array(data)
    atrgd,ftrgd,rtrgd,ptrgd,ategd,ftegd,rtegd,ptegd = 0,0,0,0,0,0,0,0
    atrsgd,ftrsgd,rtrsgd,ptrsgd,atesgd,ftesgd,rtesgd,ptesgd = 0,0,0,0,0,0,0,0
    iterations = 10
    for i in range(iterations):
        x_train, y_train, x_test, y_test = split(data)
    
        wt_gd, loss_gd, itr_gd, acc_gd_list = gd(x_train, y_train)
        Y_pred_train_gd = predict(wt_gd, x_train)
        Y_pred_test_gd = predict(wt_gd, x_test)
        
        wt_sgd, loss_sgd, itr_sgd, acc_sgd_list = sgd(x_train, y_train)
        Y_pred_train_sgd = predict(wt_sgd, x_train)
        Y_pred_test_sgd = predict(wt_sgd, x_test)
        
        acc_gd_train = accuracy(wt_gd,x_train,y_train)
        fscore_gd_train, recall_gd_train, precision_gd_train = fpr(Y_pred_train_gd,y_train)        
        acc_gd_test = accuracy(wt_gd,x_test,y_test)
        fscore_gd_test, recall_gd_test, precision_gd_test = fpr(Y_pred_test_gd,y_test)
        
        acc_sgd_train = accuracy(wt_sgd,x_train,y_train)
        fscore_sgd_train, recall_sgd_train, precision_sgd_train = fpr(Y_pred_train_sgd,y_train)        
        acc_sgd_test = accuracy(wt_sgd,x_test,y_test)
        fscore_sgd_test, recall_sgd_test, precision_sgd_test = fpr(Y_pred_test_sgd,y_test)
        
        atrgd += acc_gd_train
        ftrgd += fscore_gd_train
        rtrgd += recall_gd_train
        ptrgd += precision_gd_train
        
        ategd += acc_gd_test
        ftegd += fscore_gd_test
        rtegd += recall_gd_test
        ptegd += precision_gd_test
        
        atrsgd += acc_sgd_train
        ftrsgd += fscore_sgd_train
        rtrsgd += recall_sgd_train
        ptrsgd += precision_sgd_train
        
        atesgd += acc_sgd_test
        ftesgd += fscore_sgd_test
        rtesgd += recall_sgd_test
        ptesgd += precision_sgd_test
        
#         plot_graph_loss(itr_sgd,acc_sgd_list)
        
        print("Wt of gd:",wt_gd)
        print("Wt of sgd:",wt_sgd)
        
        print("##############################################################")
        
        print("Train Statistics using GD for ",i+1," iteration")
        
        print("Accuracy: ", "{0:.2f}".format(acc_gd_train))
        print("Fscore: ","{0:.2f}".format(fscore_gd_train))
        print("Recall: ","{0:.2f}".format(recall_gd_train))
        print("Precision: ","{0:.2f}".format(precision_gd_train))
        
        print("##############################################################")
        
        print("Test Statistics using GD for ",i+1," iteration")
#         print("Wt of gd:",wt_gd)
        print("Accuracy: ","{0:.2f}".format(acc_gd_test))
        print("Fscore: ","{0:.2f}".format(fscore_gd_test))
        print("Recall: ","{0:.2f}".format(recall_gd_test))
        print("Precision: ","{0:.2f}".format(precision_gd_test))
        
        print("##############################################################")
        
        print("Train Statistics using SGD for ",i+1," iteration")
        
        print("Accuracy: ","{0:.2f}".format(acc_sgd_train))
        print("Fscore: ","{0:.2f}".format(fscore_sgd_train))
        print("Recall: ","{0:.2f}".format(recall_sgd_train))
        print("Precision: ","{0:.2f}".format(precision_sgd_train))
        
        print("##############################################################")
        
        print("Test Statistics using SGD for ",i+1," iteration")
#         print("Wt of sgd:",wt_sgd)
        print("Accuracy: ","{0:.2f}".format(acc_sgd_test))
        print("Fscore: ","{0:.2f}".format(fscore_sgd_test))
        print("Recall: ","{0:.2f}".format(recall_sgd_test))
        print("Precision: ","{0:.2f}".format(precision_sgd_test))
        
        print("##############################################################")
        

    print("Average Train Statistics using GD")
    print("Average Accuracy: ", "{0:.2f}".format(atrgd/iterations))
    print("Average Fscore: ", "{0:.2f}".format(ftrgd/iterations))
    print("Average Recall: ", "{0:.2f}".format(rtrgd/iterations))
    print("Average Precision: ", "{0:.2f}".format(ptrgd/iterations))
    
    print("##############################################################")
    print("Average Test Statistics using GD")
    print("Average Accuracy: ","{0:.2f}".format(ategd/iterations))
    print("Average Fscore: ", "{0:.2f}".format(ftegd/iterations))
    print("Average Recall: ", "{0:.2f}".format(rtegd/iterations))
    print("Average Precision: ", "{0:.2f}".format(ptegd/iterations))
    
    print("##############################################################")
    print("Average Train Statistics using SGD")
    print("Average Accuracy: ", "{0:.2f}".format(atrsgd/iterations))
    print("Average Fscore: ", "{0:.2f}".format(ftrsgd/iterations))
    print("Average Recall: ", "{0:.2f}".format(rtrsgd/iterations))
    print("Average Precision: ", "{0:.2f}".format(ptrsgd/iterations))
    
    print("##############################################################")
    print("Average Train Statistics using SGD")
    print("Average Accuracy: ", "{0:.2f}".format(atesgd/iterations))
    print("Average Fscore: ", "{0:.2f}".format(ftesgd/iterations))
    print("Average Recall: ", "{0:.2f}".format(rtesgd/iterations))
    print("Average Precision: ", "{0:.2f}".format(ptesgd/iterations))

    end=time.time()
    print("Time taken is: ",(end-start))

# %%
main()
print('END')
# Out:
# Wt of gd: [-0.87073857 -3.9224043  -3.45094838 -3.2508374   0.31221243]
# Wt of sgd: [-0.49840162 -2.85227815 -2.1838462  -1.96072342  0.18915943]
# ##############################################################
# Train Statistics using GD for  1  iteration
# Accuracy:  97.81
# Fscore:  0.98
# Recall:  0.96
# Precision:  1.00
# ##############################################################
# Test Statistics using GD for  1  iteration
# Accuracy:  98.30
# Fscore:  0.98
# Recall:  0.97
# Precision:  0.99
# ##############################################################
# Train Statistics using SGD for  1  iteration
# Accuracy:  97.29
# Fscore:  0.97
# Recall:  0.95
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  1  iteration
# Accuracy:  98.06
# Fscore:  0.98
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Wt of gd: [-0.93897588 -3.9067179  -3.42133874 -3.22232381  0.29637233]
# Wt of sgd: [-0.55008191 -2.8732603  -2.15451229 -1.92988942  0.18803293]
# ##############################################################
# Train Statistics using GD for  2  iteration
# Accuracy:  97.92
# Fscore:  0.98
# Recall:  0.96
# Precision:  1.00
# ##############################################################
# Test Statistics using GD for  2  iteration
# Accuracy:  98.30
# Fscore:  0.98
# Recall:  0.97
# Precision:  0.99
# ##############################################################
# Train Statistics using SGD for  2  iteration
# Accuracy:  97.29
# Fscore:  0.97
# Recall:  0.95
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  2  iteration
# Accuracy:  97.57
# Fscore:  0.97
# Recall:  0.96
# Precision:  0.98
# ##############################################################
# Wt of gd: [-0.89411324 -4.0029814  -3.33939924 -3.27811677  0.36838363]
# Wt of sgd: [-0.54410004 -2.90324427 -2.11870797 -1.96913833  0.21967256]
# ##############################################################
# Train Statistics using GD for  3  iteration
# Accuracy:  98.23
# Fscore:  0.98
# Recall:  0.97
# Precision:  0.99
# ##############################################################
# Test Statistics using GD for  3  iteration
# Accuracy:  97.33
# Fscore:  0.97
# Recall:  0.94
# Precision:  1.00
# ##############################################################
# Train Statistics using SGD for  3  iteration
# Accuracy:  98.02
# Fscore:  0.98
# Recall:  0.97
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  3  iteration
# Accuracy:  95.63
# Fscore:  0.95
# Recall:  0.93
# Precision:  0.97
# ##############################################################
# Wt of gd: [-0.76333384 -3.85324508 -3.53118394 -3.29922166  0.27057062]
# Wt of sgd: [-0.41600927 -2.82535279 -2.226493   -1.99227857  0.17196737]
# ##############################################################
# Train Statistics using GD for  4  iteration
# Accuracy:  97.71
# Fscore:  0.98
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Test Statistics using GD for  4  iteration
# Accuracy:  98.30
# Fscore:  0.98
# Recall:  0.96
# Precision:  1.00
# ##############################################################
# Train Statistics using SGD for  4  iteration
# Accuracy:  97.29
# Fscore:  0.97
# Recall:  0.95
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  4  iteration
# Accuracy:  97.57
# Fscore:  0.97
# Recall:  0.94
# Precision:  1.00
# ##############################################################
# Wt of gd: [-0.90599263 -3.85538471 -3.49417026 -3.24990144  0.28053742]
# Wt of sgd: [-0.53337662 -2.83067866 -2.20411678 -1.93194893  0.17010413]
# ##############################################################
# Train Statistics using GD for  5  iteration
# Accuracy:  98.23
# Fscore:  0.98
# Recall:  0.96
# Precision:  1.00
# ##############################################################
# Test Statistics using GD for  5  iteration
# Accuracy:  97.57
# Fscore:  0.97
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Train Statistics using SGD for  5  iteration
# Accuracy:  97.50
# Fscore:  0.97
# Recall:  0.95
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  5  iteration
# Accuracy:  97.09
# Fscore:  0.97
# Recall:  0.96
# Precision:  0.98
# ##############################################################
# Wt of gd: [-0.7438486  -3.97610478 -3.42993709 -3.23276822  0.21631226]
# Wt of sgd: [-0.41578615 -2.8991564  -2.17798477 -1.93700325  0.1301987 ]
# ##############################################################
# Train Statistics using GD for  6  iteration
# Accuracy:  98.23
# Fscore:  0.98
# Recall:  0.97
# Precision:  1.00
# ##############################################################
# Test Statistics using GD for  6  iteration
# Accuracy:  95.87
# Fscore:  0.95
# Recall:  0.91
# Precision:  0.99
# ##############################################################
# Train Statistics using SGD for  6  iteration
# Accuracy:  97.60
# Fscore:  0.97
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  6  iteration
# Accuracy:  95.63
# Fscore:  0.95
# Recall:  0.91
# Precision:  0.99
# ##############################################################
# Wt of gd: [-0.91363592 -3.83824791 -3.47742841 -3.26204106  0.2987509 ]
# Wt of sgd: [-0.53789599 -2.83348633 -2.17159395 -1.93687602  0.1838613 ]
# ##############################################################
# Train Statistics using GD for  7  iteration
# Accuracy:  97.81
# Fscore:  0.98
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Test Statistics using GD for  7  iteration
# Accuracy:  98.54
# Fscore:  0.98
# Recall:  0.97
# Precision:  1.00
# ##############################################################
# Train Statistics using SGD for  7  iteration
# Accuracy:  97.08
# Fscore:  0.97
# Recall:  0.95
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  7  iteration
# Accuracy:  98.06
# Fscore:  0.98
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Wt of gd: [-0.82603875 -3.96782047 -3.4086391  -3.19472336  0.25927806]
# Wt of sgd: [-0.47320311 -2.90250688 -2.1236825  -1.87827763  0.16441188]
# ##############################################################
# Train Statistics using GD for  8  iteration
# Accuracy:  97.81
# Fscore:  0.98
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Test Statistics using GD for  8  iteration
# Accuracy:  97.82
# Fscore:  0.97
# Recall:  0.95
# Precision:  1.00
# ##############################################################
# Train Statistics using SGD for  8  iteration
# Accuracy:  97.60
# Fscore:  0.97
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  8  iteration
# Accuracy:  97.33
# Fscore:  0.97
# Recall:  0.95
# Precision:  0.99
# ##############################################################
# Wt of gd: [-0.93158986 -3.84331285 -3.51888185 -3.20687469  0.28359222]
# Wt of sgd: [-0.5486148  -2.81445068 -2.22386997 -1.88908199  0.14235211]
# ##############################################################
# Train Statistics using GD for  9  iteration
# Accuracy:  97.92
# Fscore:  0.98
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Test Statistics using GD for  9  iteration
# Accuracy:  98.06
# Fscore:  0.98
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Train Statistics using SGD for  9  iteration
# Accuracy:  97.19
# Fscore:  0.97
# Recall:  0.95
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  9  iteration
# Accuracy:  97.57
# Fscore:  0.97
# Recall:  0.96
# Precision:  0.99
# ##############################################################
# Wt of gd: [-0.89210271 -3.92930441 -3.44268093 -3.21664991  0.22245359]
# Wt of sgd: [-0.51336683 -2.86404083 -2.17367669 -1.93348704  0.13134015]
# ##############################################################
# Train Statistics using GD for  10  iteration
# Accuracy:  97.71
# Fscore:  0.98
# Recall:  0.95
# Precision:  1.00
# ##############################################################
# Test Statistics using GD for  10  iteration
# Accuracy:  98.06
# Fscore:  0.98
# Recall:  0.97
# Precision:  0.99
# ##############################################################
# Train Statistics using SGD for  10  iteration
# Accuracy:  97.19
# Fscore:  0.97
# Recall:  0.95
# Precision:  0.99
# ##############################################################
# Test Statistics using SGD for  10  iteration
# Accuracy:  97.57
# Fscore:  0.97
# Recall:  0.96
# Precision:  0.98
# ##############################################################
# Average Train Statistics using GD
# Average Accuracy:  97.94
# Average Fscore:  0.98
# Average Recall:  0.96
# Average Precision:  1.00
# ##############################################################
# Average Test Statistics using GD
# Average Accuracy:  97.82
# Average Fscore:  0.98
# Average Recall:  0.96
# Average Precision:  1.00
# ##############################################################
# Average Train Statistics using SGD
# Average Accuracy:  97.41
# Average Fscore:  0.97
# Average Recall:  0.95
# Average Precision:  0.99
# ##############################################################
# Average Train Statistics using SGD
# Average Accuracy:  97.21
# Average Fscore:  0.97
# Average Recall:  0.95
# Average Precision:  0.99
# Time taken is:  101.232990026474
# END
